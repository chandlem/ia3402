# %% [markdown]
# ## Extract Job Posts from Indeed

# %% [markdown]
# ### Create a table in database

# %%
import pandas
import configparser
import psycopg2

# %% [markdown]
# Read the database connection info from the config.ini

# %%
config = configparser.ConfigParser()
config.read('config.ini')

host = config['myaws']['host']
db = config['myaws']['database']
user = config['myaws']['user']
pwd = config['myaws']['pwd']

# %% [markdown]
# Establish a connection to the database, and create a cursor.

# %%
conn = psycopg2.connect(host = host,
                       user = user,
                        password = pwd,
                        dbname = db
                       )
cur = conn.cursor()

# %% [markdown]
# Design the table in SQL

# %%
table_sql = """
            CREATE TABLE IF NOT EXISTS indeed_gp8
            (
                id SERIAL,
                job_title VARCHAR(200),
                job_company VARCHAR(200),
                job_loc VARCHAR(200),
                job_salary VARCHAR(200),
                job_summary TEXT,
                PRIMARY KEY(id)
            );

            """

# %% [markdown]
# Create the table

# %%
cur.execute(table_sql)
conn.commit()

# %% [markdown]
# ### Request HTML

# %% [markdown]
# urllib.request makes simple HTTP requests to visit a web page and get the content via the Python standard library. Here we define the URL to search job posts about intelligence analysts.

# %%
url = 'https://www.indeed.com/jobs?q=intelligence+analyst&start=0'

# %%
import urllib.request
response = urllib.request.urlopen(url)
html_data= response.read()
#print(html_data.decode('utf-8'))

# %% [markdown]
# ## Parese HTML

# %% [markdown]
# We can use the inspector tool in browsers to analyze webpages and use beautifulsoup to extract webpage data. pip install the beautiful soup if needed.

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.6.0)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data,'html.parser')
#print (soup)

# %% [markdown]
# Use the tag.find_all(‘tag_name’, tage_attr = ‘possible_value’) function to return a list of tags where the attribute equals the possible_value.
#
# Common attributes include:
# id
# class_
#
# Common functions include:
# tag.text: return the visible part of the tag
# tag.get(‘attribute’): return the value of the attribute of the tag
#
# Since all the job posts are in the div tag class = 'jobsearch-Sprep...', we need to find that div tag from the body tag.

# %%
for table_resultsBody in soup.find_all('table', id = 'resultsBody'):
    pass
    #print(table_resultsBody)

# %%
for table_pageContent in table_resultsBody.find_all('table', id = 'pageContent'):
    pass
    #print(table_pageContent)

# %%
for td_resultsCol in table_pageContent.find_all('td', id = 'resultsCol'):
    pass
    #print(td_resultsCol)

# %% [markdown]
# ## Save Data to Database

# %% [markdown]
# Now we find the div tag contains the job posts. We need to identify the job title, company, ratings, reviews, salary, and summary. We can save those records to our table in the database.

# %%
#  identify the job title, company, ratings, reviews, salary, and summary
for div_row in td_resultsCol.find_all('div', class_='jobsearch-SerpJobCard unifiedRow row result'):

    # find job title
    job_title = None
    job_company  = None
    job_rating = None
    job_loc = None
    job_salary = None
    job_summary = None
    for div_title in div_row.find_all('div', class_ = 'title'):
        job_title = div_title.text.strip().replace("'","_")
    
    for div_dsc in div_row.find_all('div', class_ = 'sjcl'):
        
        #find company name
        for span_company in div_dsc.find_all('span', class_ = 'company'):
            job_company = span_company.text.strip().replace("'","_")
        
        # find location
        for div_loc in div_dsc.find_all('div', class_ = 'location accessible-contrast-color-location'):
            job_loc = div_loc.text.strip().replace("'","_")
    
    # find salary
    for div_salary in div_row.find_all('div',class_ ='salarySnippet'):
        job_salary = div_salary.text.strip().replace("'","_")
    
    #find summary
    for div_summary in div_row.find_all('div', class_ = 'summary'):
        job_summary = div_summary.text.strip().replace("'","_")
        
    # insert into database
    
    sql_insert = """
                insert into indeed_gp8(job_title,job_company,job_loc,job_salary,job_summary)
                values('{}','{}','{}','{}','{}')            
                """.format(job_title,job_company,job_loc,job_salary,job_summary)

    cur.execute(sql_insert)
    conn.commit()

# %% [markdown]
# ## View the Table

# %%
df = pandas.read_sql_query('select * from indeed_gp8', conn)
df[:]
# Out:
#     id                                          job_title  \
# 0    1                               Intelligence Analyst
# 1    2                   Quantitative Analyst / Developer
# 2    3           H-ISAC Cyber Threat Intelligence Analyst
# 3    4  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 4    5                             Transportation Analyst
# 5    6                                   Security Analyst
# 6    7                               Intelligence Analyst
# 7    8                       Intelligence Analyst I - MRS
# 8    9                               Intelligence Analyst
# 9   10                               Intelligence Analyst
# 10  11                               Intelligence Analyst
# 11  12  Global Intelligence & Travel Security Operatio...
# 12  13                               Intelligence Analyst
# 13  14                               Intelligence Analyst
# 14  15       Intelligence Analyst (Identity Intelligence)
# 15  16                               Intelligence Analyst
# 16  17  Undergraduate Internship/Co-op Program - Intel...
# 17  18               Associate Cyber Intelligence Analyst
# 18  19                               Intelligence Analyst
# 19  20                        Intelligence Senior Analyst
# 20  21  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 21  22                         Brand Intelligence Analyst
# 22  23                                    Vetting Analyst
# 23  24           H-ISAC Cyber Threat Intelligence Analyst
# 24  25                      Acoustic Intelligence Analyst
# 25  26       Intelligence Analyst (Identity Intelligence)
# 26  27              Intelligence Specialist (GMI Analyst)
# 27  28                         OSINT Intelligence Analyst
# 28  29              Intelligence Specialist (S&T Analyst)
# 29  30  Junior Identity Intelligence Analyst (TS/SCI C...
# 30  31                               Intelligence Analyst
# 31  32  All source Sr. Intelligence Analyst - ( TS wit...
# 32  33                               Intelligence Analyst
# 33  34  Mid-Level Intelligence Analyst (TS/SCI Clearance)
# 34  35               Intelligence Specialist (Operations)
# 35  36               Associate Cyber Intelligence Analyst
# 36  37  Undergraduate Internship/Co-op Program - Intel...
#
#                           job_company                            job_loc  \
# 0            National Security Agency                     Fort Meade, MD
# 1                           RT Signal  New York, NY 10013 (Tribeca area)
# 2                      Perch Security                     Titusville, FL
# 3                             Maveris                    Martinsburg, WV
# 4                 Lipman Family Farms                Immokalee, FL 34142
# 5                      Seen by Indeed                     Washington, DC
# 6                 Booz Allen Hamilton                               None
# 7                          WorldAware                               None
# 8                         BAE Systems                               None
# 9               5 Stones intelligence                               None
# 10           National Security Agency                               None
# 11                          Pinkerton                               None
# 12             Red Five Security, LLC                               None
# 13                             Splunk                               None
# 14             Signature Science, LLC                               None
# 15                IntelliWare Systems                               None
# 16        Central Intelligence Agency                     Washington, DC
# 17       LookingGlass Cyber Solutions                   Reston, VA 20191
# 18           National Security Agency                     Fort Meade, MD
# 19                               Citi                    Tampa, FL 33646
# 20                            Maveris                    Martinsburg, WV
# 21       LookingGlass Cyber Solutions                   Reston, VA 20191
# 22  ManTech International Corporation               Colorado Springs, CO
# 23                     Perch Security                     Titusville, FL
# 24                          Perspecta                 Suitland, MD 20746
# 25             Signature Science, LLC                               None
# 26          US Department of the Army                               None
# 27                   Northrop Grumman                               None
# 28          US Department of the Army                               None
# 29                          Inflow-ns                               None
# 30                Booz Allen Hamilton                               None
# 31                   VISUAL SOFT, INC                               None
# 32                       Salient CRGT                               None
# 33                          Inflow-ns                               None
# 34          US Department of the Army                               None
# 35       LookingGlass Cyber Solutions                   Reston, VA 20191
# 36        Central Intelligence Agency                     Washington, DC
#
#                    job_salary  \
# 0    $47,016 - $74,759 a year
# 1   $95,000 - $165,000 a year
# 2    $50,000 - $75,000 a year
# 3    $60,000 - $70,000 a year
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
# 10   $47,016 - $74,759 a year
# 11                       None
# 12                       None
# 13                       None
# 14                       None
# 15                       None
# 16    $21.21 - $22.43 an hour
# 17                       None
# 18   $47,016 - $74,759 a year
# 19                       None
# 20   $60,000 - $70,000 a year
# 21                       None
# 22                       None
# 23   $50,000 - $75,000 a year
# 24                       None
# 25                       None
# 26  $88,704 - $115,313 a year
# 27                       None
# 28  $88,704 - $115,313 a year
# 29                       None
# 30                       None
# 31             $97,000 a year
# 32                       None
# 33                       None
# 34   $74,596 - $96,978 a year
# 35                       None
# 36    $21.21 - $22.43 an hour
#
#                                           job_summary
# 0   The National Security Agency (NSA) is part of ...
# 1   We are a small, but well-funded (financially s...
# 2   Ability to communicate technical issues to tec...
# 3   The Analyst can identify risks in security sys...
# 4   Perform fact based, data driven analysis, and ...
# 5   Get matched – Companies apply to you with oppo...
# 6   We’re an EOE that empowers our people—no matte...
# 7   WorldAware is dedicated to equal opportunity i...
# 8   Having an understanding of physical and techni...
# 9   Analyze threat information from multiple sourc...
# 10  The National Security Agency (NSA) is part of ...
# 11  The Global Intelligence & Travel Security Oper...
# 12  We do not discriminate on the basis of race, r...
# 13  All qualified applicants will receive consider...
# 14  The purpose of this position is to provide tec...
# 15  The analyst will provide terrorist related thr...
# 16  Engineering, science students, or those in oth...
# 17  Past experience in intelligence, technology, c...
# 18  The National Security Agency (NSA) is part of ...
# 19  If you are a person with a disability and need...
# 20  The Analyst can identify risks in security sys...
# 21  The Brand Intelligence Analyst employs our pro...
# 22  We do not discriminate against any employee or...
# 23  Ability to communicate technical issues to tec...
# 24  We provide solutions to improve the Nation_s d...
# 25  The purpose of this position is to provide tec...
# 26  Specialized experience is defined as experienc...
# 27  We are proud to be an Equal Opportunity/Affirm...
# 28  Interpret data collected from multiple sources...
# 29  Prior active duty military experience or at le...
# 30  We’re an EOE that empowers our people—no matte...
# 31  Active Top Secret with SCI is a MUST.As part o...
# 32  All qualified applicants will receive consider...
# 33  Prior active duty military experience or at le...
# 34  One year of specialized experience equivalent ...
# 35  Past experience in intelligence, technology, c...
# 36  Engineering, science students, or those in oth...

# %%
cur.close()
conn.close()
